# %%
### 여행 데이터 - travel type 라벨링 하기
- 자연친화족 : 바다, 산, 별빛
- 도시족 : 야경, 관광, 쇼핑
- 지식추구족 : 역사(궁, 사원, 건축물)
- 문화예술족 : 박물관, 미술관
- 도전족 : 캠핑, 하이킹
차량, 테마파크: 가족적
체험 클래스: 체험중시

도보/차량 여부

# %%
df_type = pd.read_csv("../data/activity_keyword_type_1.csv", encoding='cp949', index_col=0).reset_index()
df_type
# Out:
#    city_name  activity                                          tour_name  \
# 0         뉴욕      9660                 아트어드바이저와 함께 하는 아트 뉴욕-메트로폴리탄 미술관 투어
# 1         뉴욕      5665     뉴욕 미술가 와 함께하는 미술다큐 1 " 뉴욕의 미술관 " 모마 또는 휘트니 뮤지엄
# 2         뉴욕      2097                                           뉴욕 야경 투어
# 3         뉴욕      5833                                  덤보+야경투어 뉴요커처럼 즐기기
# 4         뉴욕      6282  뉴욕 미술가와 함께하는 미술다큐 2 " 뉴욕의 미술관 " ( Met ) 메트로폴리탄 투어
# 5         뉴욕     10504                 맨하탄 미드타운 다운타운 차량 투어(자유의 여신상 페리 포함)
# 6         뉴욕       714                                        뉴욕 단독 차량 투어
# 7         뉴욕        84                                      낮투어 뉴욕 제대로 보기
# 8         뉴욕      5981                          [주말 투어] 뉴욕 핫 포토 스팟(스냅 포함)
# 9        하와이      6507      [투어] 한가족만! 지상의 낙원 하와이를 천천히~여유롭게~하루만에 알짜배기 투어!
# 10       하와이     41529                                [투어] 쿠알로아 목장 미국/하와이
# 11       하와이      6561  [투어] 호놀룰루 야경 & 최고의 별미 하와이 도너츠 (말라사다) 맛탐방 :: 미국...
# ...

# %%
act = pd.read_csv("../data/activity_cleared_with_corpus.csv", index_col=0).reset_index()
del act['index']
act
# Out:
#     label city_name  activity  \
# 0       3        뉴욕      9660
# 1       3        뉴욕      5665
# 2       3        뉴욕      2097
# 3       3        뉴욕      5833
# 4       3        뉴욕      6282
# ..    ...       ...       ...
# 67      3      베네치아     33306
# 68      3      베네치아     26036
# 69      3      베네치아     52950
# 70      3      베네치아     17175
# 71      3      베네치아     38413
#
#                                                review  \
# 0   이**\n40대출장, 학회로 가는 여행2020-03-11\n3시간 순삭가는 즐거운시...
# 1   박**\n40대혼자 가는 여행2020-04-24\n벌써 1년 전이네요..요즘 같은 ...
# 2   이**\n30대친구들과 가는 여행2020-02-18\n야경 투어 편하게 했네요~\n...
# 3   최**\n30대혼자 가는 여행2020-02-18\n야간 투어 핫 스팟\n로컬 라이브...
# 4   세*\n30대혼자 가는 여행2020-02-22\n그냥 혼자 봤으면 몰랐을 이야기들도...
# ..                                                ...
# 67  정**\n30대허니문 여행2020-03-11\n부라노 투어 시작전에 먹는 피자는 꿀...
# 68  손**\n20대친구들과 가는 여행2020-02-26\n.\n홍**\n30대혼자 가는...
# 69  윤**\n20대혼자 가는 여행2020-02-18\n정말 꼼꼼 하게 설명해주시고 베네...
# ...

# %%
### 베네치아
    - 야경투어
    -
