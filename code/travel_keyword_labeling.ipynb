# %%
### 여행 데이터 - travel type 라벨링 하기
- 자연친화족 : 바다, 산, 별빛
- 도시족 : 야경, 관광, 쇼핑
- 지식추구족 : 역사(궁, 사원, 건축물)
- 문화예술족 : 박물관, 미술관
- 도전족 : 캠핑, 하이킹
차량, 테마파크: 가족적
체험 클래스: 체험중시

도보/차량 여부

# %%
df_type = pd.read_csv("./data_set/activity_keyword_type.csv", encoding='cp949', index_col=0).reset_index()
df_type
# Out:
#    city_name  activity                                          tour_name  \
# 0         뉴욕      9660                 아트어드바이저와 함께 하는 아트 뉴욕-메트로폴리탄 미술관 투어
# 1         뉴욕      5665     뉴욕 미술가 와 함께하는 미술다큐 1 " 뉴욕의 미술관 " 모마 또는 휘트니 뮤지엄
# 2         뉴욕      2097                                           뉴욕 야경 투어
# 3         뉴욕      5833                                  덤보+야경투어 뉴요커처럼 즐기기
# 4         뉴욕      6282  뉴욕 미술가와 함께하는 미술다큐 2 " 뉴욕의 미술관 " ( Met ) 메트로폴리탄 투어
# 5         뉴욕     10504                 맨하탄 미드타운 다운타운 차량 투어(자유의 여신상 페리 포함)
# 6         뉴욕       714                                        뉴욕 단독 차량 투어
# 7         뉴욕        84                                      낮투어 뉴욕 제대로 보기
# 8         뉴욕      5981                          [주말 투어] 뉴욕 핫 포토 스팟(스냅 포함)
# 9        하와이      6507      [투어] 한가족만! 지상의 낙원 하와이를 천천히~여유롭게~하루만에 알짜배기 투어!
# 10       하와이     41529                                [투어] 쿠알로아 목장 미국/하와이
# 11       하와이      6561  [투어] 호놀룰루 야경 & 최고의 별미 하와이 도너츠 (말라사다) 맛탐방 :: 미국...
# ...
